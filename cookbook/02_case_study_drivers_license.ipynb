# %% [markdown]
# <div align="center">
# <p align="center" style="width: 100%;">
#     <img src="https://raw.githubusercontent.com/vlm-run/.github/refs/heads/main/profile/assets/vlm-black.svg" alt="VLM Run Logo" width="80" style="margin-bottom: -5px; color: #2e3138; vertical-align: middle; padding-right: 5px;"><br>
# </p>
# <p align="center"><a href="https://docs.vlm.run"><b>Website</b></a> | <a href="https://docs.vlm.run/"><b>API Docs</b></a> | <a href="https://docs.vlm.run/blog"><b>Blog</b></a> | <a href="https://discord.gg/AMApC2UzVY"><b>Discord</b></a>
# </p>
# <p align="center">
# <a href="https://discord.gg/AMApC2UzVY"><img alt="Discord" src="https://img.shields.io/badge/discord-chat-purple?color=%235765F2&label=discord&logo=discord"></a>
# <a href="https://twitter.com/vlmrun"><img alt="Twitter Follow" src="https://img.shields.io/twitter/follow/vlmrun.svg?style=social&logo=twitter"></a>
# </p>
# </div>
#
# Welcome to the [VLM Run](https://vlm.run) Colab Cookbook! This notebook serves as an example to help developers leverage the power of Vision Language Models (VLMs) for visual content extraction and transformation into structured JSON.

# %% [markdown]
# ### Environment Setup
#
# To get started, install the VLM Run Python SDK and sign-up for an API key on the [VLM Run App](https://app.vlm.run).
# - Store the VLM Run API key under the `VLMRUN_API_KEY` environment variable.

# %% [markdown]
# ## Setup
#
# First, let's install the required packages:

# %%
! pip install vlmrun --upgrade --quiet
! pip install vlmrun-hub --upgrade --quiet

# %%
! pip install pandas google-cloud-storage openai --quiet

# %%
import os
import getpass

VLMRUN_BASE_URL = os.getenv("VLMRUN_BASE_URL", "https://dev.vlm.run/v1")
VLMRUN_API_KEY = os.getenv("VLMRUN_API_KEY", None)
if VLMRUN_API_KEY is None:
    VLMRUN_API_KEY = getpass.getpass()
# Out:
#  ········

# %%
import pandas as pd
from PIL import Image

from vlmrun.common.image import encode_image
from vlmrun.common.utils import remote_image
from pathlib import Path
from google.cloud import storage

# %%
BUCKET_NAME = "vlm-data-public-prod"
PREFIX = "hub/examples/document.us-drivers-license/us-dataset-2025-01-22"

storage_client = storage.Client.create_anonymous_client()
bucket = storage_client.bucket(BUCKET_NAME)
blobs = bucket.list_blobs(prefix=PREFIX)

image_urls = [
    f"https://storage.googleapis.com/{BUCKET_NAME}/{blob.name}"
    for blob in blobs
    if any(blob.name.lower().endswith(ext) for ext in ['.jpg', '.jpeg', '.png'])
]

# %%
df = pd.DataFrame({
    "image_path": image_urls,
    "image": [remote_image(url) for url in image_urls]
})

print(f"Loaded {len(image_urls)} driver's license images")
df.head()
# Out:
# Loaded 54 driver's license images
#                                           image_path  \
# 0  https://storage.googleapis.com/vlm-data-public...
# 1  https://storage.googleapis.com/vlm-data-public...
# 2  https://storage.googleapis.com/vlm-data-public...
# 3  https://storage.googleapis.com/vlm-data-public...
# 4  https://storage.googleapis.com/vlm-data-public...
#
#                                                image
# 0  <PIL.Image.Image image mode=RGB size=650x406 a...
# 1  <PIL.Image.Image image mode=RGB size=514x328 a...
# 2  <PIL.Image.Image image mode=RGB size=700x439 a...
# 3  <PIL.Image.Image image mode=RGB size=700x450 a...
# 4  <PIL.Image.Image image mode=RGB size=700x448 a...

# %%
import json
from IPython.display import HTML, display

formatters = {
    "image": lambda x: f"<img src='{encode_image(x, format='JPEG')}' width='300'>"
}
cols = ["image_path", "image"]
display(HTML(df[cols].head(n=10).to_html(formatters=formatters, escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>image_path</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Alabama.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Alaska.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Arizona.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Arkansas.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/California.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Colorado.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Connecticut.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Delaware.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Florida.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>https://storage.googleapis.com/vlm-data-public-prod/hub/examples/document.us-drivers-license/us-dataset-2025-01-22/Georgia.jpg</td>
#       <td><img src='data:image/jpeg;base64,...' width='300'></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's initialize the VLM Run Client

# %%
from vlmrun.client import VLMRun

vlm_client = VLMRun(base_url=VLMRUN_BASE_URL, api_key=VLMRUN_API_KEY)

# %%
## Dry run test on one of the images with VLM Run Client

response = vlm_client.image.generate(
    images=[df["image"][0]],
    domain="document.us-drivers-license"
)

print(response)
display(df["image"][0])
# Out:
# id='2d481f57-80ab-4e88-9267-94bbc9186403' created_at=datetime.datetime(2025, 2, 7, 9, 55, 34, 773323) completed_at=datetime.datetime(2025, 2, 7, 9, 55, 38, 736636, tzinfo=TzInfo(UTC)) response={'issuing_state': 'AL', 'license_number': '1234567', 'full_name': 'CONNOR SAMPLE', 'first_name': 'CONNOR', 'middle_name': None, 'last_name': 'SAMPLE', 'address': {'street': '1 WONDERFUL DRIVE', 'city': 'MONTGOMERY', 'state': 'AL', 'zip_code': '36104-1234'}, 'date_of_birth': '1948-01-05', 'gender': 'M', 'height': '5\'05"', 'weight': 120.0, 'eye_color': 'BLU', 'hair_color': 'BLN', 'issue_date': '2010-01-05', 'expiration_date': '2014-01-05', 'license_class': 'D', 'donor': True, 'veteran': None} status='completed' usage=CreditUsage(elements_processed=1, element_type='image', credits_used=1)
# <PIL.Image.Image image mode=RGB size=650x406>

# %% [markdown]
# Let's initialize the OpenAI client to compare it with VLM Run

# %%
from openai import OpenAI

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", None)

if OPENAI_API_KEY is None:
    OPENAI_API_KEY = getpass.getpass()
# Out:
#  ········

# %%
openai_client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# We need to import the US driver license schema from the VLM Run Hub

# %%
from vlmrun.hub.schemas.document.us_drivers_license import USDriversLicense
from vlmrun.hub.utils import patch_response_format

# Dry run test with openai client
openai_response = openai_client.beta.chat.completions.parse(
    model="gpt-4o-mini",
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": "Extract the driver's license details."},
            {"type": "image_url", "image_url": {"url": encode_image(df["image"][0], format="JPEG")}}
        ],
    }],
    response_format=patch_response_format(USDriversLicense),
    temperature=0,
)

# %%
openai_response
# Out:
# ParsedChatCompletion[USDriversLicense_patched](id='chatcmpl-AyFNkxrUKowFvKhF078Xkq3otznFk', choices=[ParsedChoice[USDriversLicense_patched](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[USDriversLicense_patched](content='{"issuing_state":"AL","license_number":"1234567","full_name":"CONNOR SAMPLE","first_name":"CONNOR","middle_name":null,"last_name":"SAMPLE","address":{"street":"1 WONDERFUL DRIVE","city":"MONTGOMERY","state":"AL","zip_code":"36104-1234"},"date_of_birth":"01-05-1948","gender":"M","height":"5\'5\\"","weight":120,"eye_color":"BLU","hair_color":"BLN","issue_date":"01-05-2010","expiration_date":"01-05-2014","license_class":"D","donor":null,"veteran":null}', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[], parsed=USDriversLicense_patched(issuing_state='AL', license_number='1234567', full_name='CONNOR SAMPLE', first_name='CONNOR', middle_name=None, last_name='SAMPLE', address=Address_patched(street='1 WONDERFUL DRIVE', city='MONTGOMERY', state='AL', zip_code='36104-1234'), date_of_birth='01-05-1948', gender=<Gender.MALE: 'M'>, height='5\'5"', weight=120.0, eye_color='BLU', hair_color='BLN', issue_date='01-05-2010', expiration_date='01-05-2014', license_class=<LicenseClass.D: 'D'>, donor=None, veteran=None)))], created=1738922172, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_bd83329f63', usage=CompletionUsage(completion_tokens=145, prompt_tokens=1363, total_tokens=1508, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
from vlmrun.hub.schemas.document.us_drivers_license import USDriversLicense

def get_responses(df: pd.DataFrame) -> pd.DataFrame:
    
    def process_single_image(image):
        vlm_response = vlm_client.image.generate(
            images=[image],
            domain="document.us-drivers-license"
        )
        
        openai_response = openai_client.beta.chat.completions.parse(
            model="gpt-4o-mini",
            messages=[{
                "role": "user",
                "content": [
                    {"type": "text", "text": "Extract the driver's license details."},
                    {"type": "image_url", "image_url": {"url": encode_image(image, format="JPEG")}}
                ],
            }],
            response_format=patch_response_format(USDriversLicense),
            temperature=0,
        )
        
        return pd.Series({
            'vlm_response': vlm_response,
            'openai_response': openai_response
        })
    
    # Process all images and combine results
    responses = df['image'].apply(process_single_image)
    return pd.concat([df, responses], axis=1)

# %%
df_results = get_responses(df)

# %%
def format_comparison(row):
    return f"""
    <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px;">
        <div style="display: flex; gap: 20px;">
            <div style="flex: 1;">
                <h4>Image</h4>
                <img src='{encode_image(row["image"], format="JPEG")}' width='300'>
            </div>
            <div style="flex: 2;">
                <div style="display: flex; gap: 20px;">
                    <div style="flex: 1;">
                        <h4>VLM Run</h4>
                        <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
{json.dumps(row["vlm_response"].response, indent=2)}</pre>
                    </div>
                    <div style="flex: 1;">
                        <h4>OpenAI</h4>
                        <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
{json.dumps(json.loads(row["openai_response"].choices[0].message.parsed.model_dump_json()), indent=2)}</pre>
                    </div>
                </div>
            </div>
        </div>
    </div>
    """
    
display(HTML(
    df_results.head(10).apply(format_comparison, axis=1)
    .str.cat(sep='\n')
))
# Out:
#     <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px;">
#         <div style="display: flex; gap: 20px;">
#             <div style="flex: 1;">
#                 <h4>Image</h4>
#                 <img src='data:image/jpeg;base64,...' width='300'>
#             </div>
#             <div style="flex: 2;">
#                 <div style="display: flex; gap: 20px;">
#                     <div style="flex: 1;">
#                         <h4>VLM Run</h4>
#                         <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
# {
#   "issuing_state": "AL",
#   "license_number": "1234567",
#   "full_name": "CONNOR SAMPLE",
#   "first_name": "CONNOR",
#   "middle_name": null,
#   "last_name": "SAMPLE",
#   "address": {
#     "street": "1 WONDERFUL DRIVE",
#     "city": "MONTGOMERY",
#     "state": "AL",
#     "zip_code": "36104-1234"
#   },
#   "date_of_birth": "1948-01-05",
#   "gender": "M",
#   "height": "5'5\"",
#   "weight": 120.0,
#   "eye_color": "BLU",
#   "hair_color": "BLN",
#   "issue_date": "2010-01-05",
#   "expiration_date": "2014-01-05",
#   "license_class": "D",
#   "donor": true,
#   "veteran": null
# }</pre>
#                     </div>
#                     <div style="flex: 1;">
#                         <h4>OpenAI</h4>
#                         <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
# {
#   "issuing_state": "AL",
#   "license_number": "1234567",
#   "full_name": "CONNOR SAMPLE",
#   "first_name": "CONNOR",
#   "middle_name": null,
#   "last_name": "SAMPLE",
#   "address": {
#     "street": "1 WONDERFUL DRIVE",
#     "city": "MONTGOMERY",
#     "state": "AL",
#     "zip_code": "36104-1234"
#   },
#   "date_of_birth": "01-05-1948",
#   "gender": "M",
#   "height": "5'5\"",
#   "weight": 120.0,
#   "eye_color": "BLU",
#   "hair_color": "BLN",
#   "issue_date": "01-05-2010",
#   "expiration_date": "01-05-2014",
#   "license_class": "D",
#   "donor": null,
#   "veteran": null
# }</pre>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#
#     <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px;">
#         <div style="display: flex; gap: 20px;">
#             <div style="flex: 1;">
#                 <h4>Image</h4>
#                 <img src='data:image/jpeg;base64,...' width='300'>
#             </div>
#             <div style="flex: 2;">
#                 <div style="display: flex; gap: 20px;">
#                     <div style="flex: 1;">
#                         <h4>VLM Run</h4>
#                         <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
# {
#   "issuing_state": "AK",
#   "license_number": "7158184",
#   "full_name": "TEST ALASKA",
#   "first_name": "TEST",
#   "middle_name": null,
#   "last_name": "ALASKA",
#   "address": {
#     "street": "123 SAMPLE STREET",
#     "city": "ANCHORAGE",
#     "state": "AK",
#     "zip_code": "99501"
#   },
#   "date_of_birth": "1988-07-11",
#   "gender": "F",
#   "height": "7'07\"",
#   "weight": 440.0,
#   "eye_color": "GRN",
#   "hair_color": null,
#   "issue_date": "2018-08-03",
#   "expiration_date": "2022-07-11",
#   "license_class": "D",
#   "donor": null,
#   "veteran": null
# }</pre>
#                     </div>
#                     <div style="flex: 1;">
#                         <h4>OpenAI</h4>
#                         <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
# {
#   "issuing_state": "AK",
#   "license_number": "7158184",
#   "full_name": "TEST",
#   "first_name": "TEST",
#   "middle_name": null,
#   "last_name": "ALASKA",
#   "address": {
#     "street": "123 SAMPLE STREET",
#     "city": "ANCHORAGE",
#     "state": "AK",
#     "zip_code": "99501"
#   },
#   "date_of_birth": "07/11/1988",
#   "gender": "F",
#   "height": "7'0\"",
#   "weight": 440.0,
#   "eye_color": "GRN",
#   "hair_color": null,
#   "issue_date": "08/03/2018",
#   "expiration_date": "07/11/2022",
#   "license_class": "D",
#   "donor": null,
#   "veteran": null
# }</pre>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#
#     <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px;">
#         <div style="display: flex; gap: 20px;">
#             <div style="flex: 1;">
#                 <h4>Image</h4>
#                 <img src='data:image/jpeg;base64,...' width='300'>
#             </div>
#             <div style="flex: 2;">
#                 <div style="display: flex; gap: 20px;">
#                     <div style="flex: 1;">
#                         <h4>VLM Run</h4>
#                         <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
# {
#   "issuing_state": "AZ",
#   "license_number": "D08954796",
#   "full_name": "Jelani Sample",
#   "first_name": null,
#   "middle_name": null,
#   "last_name": null,
#   "address": {
#     "street": "123 Main St",
#     "city": "Phoenix",
#     "state": "AZ",
#     "zip_code": "85007"
#   },
#   "date_of_birth": "1974-01-01",
#   "gender": "M",
#   "height": "5'09\"",
#   "weight": 185.0,
#   "eye_color": "BRO",
#   "hair_color": "BRO",
#   "issue_date": "2016-03-01",
#   "expiration_date": "2024-03-01",
#   "license_class": "D",
#   "donor": true,
#   "veteran": true
# }</pre>
#                     </div>
#                     <div style="flex: 1;">
#                         <h4>OpenAI</h4>
#                         <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
# {
#   "issuing_state": "AZ",
#   "license_number": "D089547896",
#   "full_name": "JELANI SAMPLE",
#   "first_name": "JELANI",
#   "middle_name": null,
#   "last_name": "SAMPLE",
#   "address": {
#     "street": "123 MAIN ST",
#     "city": "PHOENIX",
#     "state": "AZ",
#     "zip_code": "85007"
#   },
#   "date_of_birth": "01/01/1974",
#   "gender": "M",
#   "height": "5'09\"",
#   "weight": 185.0,
#   "eye_color": "BRO",
#   "hair_color": "BRO",
#   "issue_date": "03/01/2016",
#   "expiration_date": "03/01/2024",
#   "license_class": "D",
#   "donor": true,
#   "veteran": true
# }</pre>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#
#     <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px;">
#         <div style="display: flex; gap: 20px;">
#             <div style="flex: 1;">
#                 <h4>Image</h4>
#                 <img src='data:image/jpeg;base64,...' width='300'>
#             </div>
#             <div style="flex: 2;">
#                 <div style="display: flex; gap: 20px;">
#                     <div style="flex: 1;">
#                         <h4>VLM Run</h4>
#                         <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
# {
#   "issuing_state": "AR",
#   "license_number": "999999999",
#   "full_name": "SAMPLE NICK",
#   "first_name": "NICK",
#   "middle_name": null,
#   "last_name": "SAMPLE",
#   "address": {
#     "street": "123 NORTH STREET",
#     "city": "CITY",
#     "state": "AR",
#     "zip_code": "12345"
#   },
#   "date_of_birth": "1960-03-05",
#   "gender": "M",
#   "height": "5'-10\"",
#   "weight": null,
#   "eye_color": "BRO",
#   "hair_color": null,
#   "issue_date": "2018-03-05",
#   "expiration_date": "2026-03-05",
#   "license_class": "D",
#   "donor": null,
#   "veteran": null
# }</pre>
#                     </div>
#                     <div style="flex: 1;">
#                         <h4>OpenAI</h4>
#                         <pre style="background: #f5f5f5; padding: 10px; border-radius: 5px;">
# {
#   "issuing_state": "AR",
#   "license_number": "9999999999",
#   "full_name": "Nick Sample",
#   "first_name": "Nick",
#   "middle_name": null,
#   "last_name": "Sample",
#   "address": {
#     "street": "123 NORTH STREET",
#     "city": "CITY",
#     "state": "AR",
#     "zip_code": "12345"
#   },
#   "date_of_birth": "03/05/1960",
#   "gender": "M",
#   "height": "5'10\"",
#   "weight": null,
#   "eye_color": "BRO",
#   "hair_color": null,
#   "issue_date": "03/05/2018",
#   "expiration_date": "03/05/2026",
#   "license_class": "D",
#   "donor": null,
#   "veteran": null
# }</pre>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#
#     <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px;">
#         <div style="display: flex; gap: 20p
